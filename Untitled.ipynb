# %%
# %run chesslytics.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /var/folders/39/n8p80q7s1b13_khp67kt_dlw0000gn/T/ipykernel_39486/2557638436.py:146
#     144 # Example usage
#     145 username = "jlee2327"
# --> 146 df = fetch_and_process_game_data(username)
#     148 print(df['white_result'].unique())
#
# File /var/folders/39/n8p80q7s1b13_khp67kt_dlw0000gn/T/ipykernel_39486/2557638436.py:133, in fetch_and_process_game_data(username, engine_path)
#     105  moves = extract_moves_from_pgn(pgn)
#     107 # print(game['eco'])
#     108
#     109  # Prepare the data dictionary for each game
#     110  data = {
#     111      'url': game['url'],
#     112      'pgn': pgn,
#     113      'moves': moves,
#     114      'date': date,
#     115      'start_time': start_time,
#     116      'end_time': end_time,
#     117      'time_spent': time_spent,
#     118      'link': link,
# ...
